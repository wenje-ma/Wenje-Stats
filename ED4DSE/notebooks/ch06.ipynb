# %% [markdown]
# # Chapter 6: Screening Designs
#
# This notebook reproduces the figures in `R/files/Ch6.R` using the Python implementation in `src/pyexpdes/chapters/ch06_screening_designs.py`.
#
# **Sections covered:**
# - 6.1 Sensitivity Analysis (variance-based, derivative-based)
# - 6.2 Morris screening design
# - 6.3 MOFAT designs
#
# **Policy**
# - Python-first implementation.
# - R wrappers used for: sensitivity (Sobol, DELSA, Morris), MOFAT.
#
# All figures are written to `figures/ch06/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch06_screening_designs import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/sobol_main_effects.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/delsa_boxplot.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/variance_vs_derivative.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/morris_design.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/morris_analysis.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/sobol_design.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch06/mofat_design.png'),
# ...

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
