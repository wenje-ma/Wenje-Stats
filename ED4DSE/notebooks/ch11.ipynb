# %% [markdown]
# # Chapter 11: Data Analysis
#
# This notebook reproduces the figures in `R/files/Ch11.R` using the Python implementation in `src/pyexpdes/chapters/ch11_data_analysis.py`.
#
# **Sections covered:**
# - 11.1 Factor Selection and Ranking (FIRST algorithm, RF/GP comparison)
# - 11.2 Twin-Gaussian Process (TwinGP)
#
# **Policy**
# - Python-first implementation for plotting.
# - R wrappers used for: first, randomForest, rkriging, SPlit, twingp.
#
# All figures are written to `figures/ch11/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch11_data_analysis import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch11'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch11/fig11_1_effects_sobol.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch11/fig11_1b_first_results.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch11/fig11_2_factor_comparison.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch11/fig11_3_twingp.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
