# %% [markdown]
# # Chapter 9: Model Calibration
#
# This notebook reproduces the figures in `R/files/Ch9.R` using the Python implementation in `src/pyexpdes/chapters/ch09_model_calibration.py`.
#
# **Sections covered:**
# - 9.1.1 Analytical Models (SO2 nonlinear regression)
# - 9.1.2 Computationally Expensive Models (Functional output Kriging)
# - 9.2.1 Parameter Uncertainties (Locally D-optimal vs Robust design)
# - 9.2.2 Model Uncertainties (MaxPro augmentation)
#
# **Policy**
# - Python-first implementation for plotting.
# - R wrappers used for: ICAOD, rkriging, FNN, numDeriv, support, MaxPro.
#
# All figures are written to `figures/ch09/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch09_model_calibration import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09/fig9_0_icaod_designs.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09/fig9_1_functional_optimal.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09/fig9_2_robust_design.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09/fig9_3_model_prediction.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch09/fig9_4_augment_design.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
