# %% [markdown]
# # Chapter 10: Data Subsampling
#
# This notebook reproduces the figures in `R/files/Ch10.R` using the Python implementation in `src/pyexpdes/chapters/ch10_data_subsampling.py`.
#
# **Sections covered:**
# - 10.1 Support Points-based Subsampling (sp, subsample)
# - 10.2 Data Splitting (SPlit)
# - 10.3 Data Twinning (twin, energy distance, spatial balance)
# - 10.4 Supervised Compression (supercompress vs K-means)
#
# **Policy**
# - Python-first implementation for plotting.
# - R wrappers used for: support, SPlit, twinning, BalancedSampling, supercompress, rkriging.
#
# All figures are written to `figures/ch10/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch10_data_subsampling import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_1_support_subsample.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_2_wind_gp.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_3_split.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_4_twinning.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_5_sampling_comparison.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch10/fig10_6_supercompress.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
