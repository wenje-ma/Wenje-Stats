# %% [markdown]
# # Chapter 3
#
# This notebook reproduces the figures in `R/files/ch3.R` using the Python implementation in `src/pyexpdes/chapters/ch03_model_based_designs.py`.
#
# **Policy**
# - Pure Python implementation (no R required).
#
# All figures are written to `figures/ch03/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch03_model_based_designs import generate_figures

out_dir, fig_paths = generate_figures()
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch03'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch03/random_designs.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch03/rmse_panels.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch03/relative_efficiency.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch03/entropy_designs.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
