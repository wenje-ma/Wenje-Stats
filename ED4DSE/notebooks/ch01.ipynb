# %% [markdown]
# # Chapter 1: Introduction
#
# This notebook reproduces the figures in `R/files/Ch1.R` using the Python implementation in `src/pyexpdes/chapters/ch01_introduction.py`.
#
# **Policy**
# - Python-first implementation.
# - R is used **only** where required to match the book outputs:
#   - `support::sp` for the space-filling design in the "uncertainty propagation" panel.
#   - `rkriging` for the Gaussian process regression panel.
#
# All figures are written to `figures/ch01/` and displayed below.

# %%
import sys
from pathlib import Path

# Ensure ../ is importable
src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch01_introduction import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch01'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch01/design_objectives.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch01/regression_comparison.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
