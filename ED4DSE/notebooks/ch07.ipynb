# %% [markdown]
# # Chapter 7: Sequential Designs
#
# This notebook reproduces the figures in `R/files/Ch7.R` using the Python implementation in `src/pyexpdes/chapters/ch07_sequential_designs.py`.
#
# **Sections covered:**
# - 7.1 Emulation (prediction-based sequential design: ALC, ALMV, ALM)
# - 7.2 Optimization (Expected Improvement)
# - 7.3 Inverse designs (OSFD)
#
# **Policy**
# - Python-first implementation for plotting.
# - R wrappers used for: rkriging, MaxPro, spacefillr, FNN, pdist, OSFD.
# - Sequential algorithms (ALC, ALMV, ALM) run entirely in R due to complex kriging operations.
#
# All figures are written to `figures/ch07/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch07_sequential_designs import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07/sequential_alc.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07/sequential_almv.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07/sequential_alm.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07/expected_improvement.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch07/osfd.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
