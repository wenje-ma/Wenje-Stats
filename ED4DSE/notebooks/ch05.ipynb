# %% [markdown]
# # Chapter 5: Representative Points
#
# This notebook reproduces the figures in `R/files/Ch5.R` using the Python implementation in `src/pyexpdes/chapters/ch05_representative_points.py`.
#
# **Sections covered:**
# - 5.1 Uniform Design (uniformity, Sobol sequences, discrepancy)
# - 5.2 Nonuniform distributions (transformation methods, support points, uncertainty propagation)
#
# **Note:** Section 5.2.4 (PQMC) is excluded due to external GitHub dependency.
#
# **Policy**
# - Python-first implementation.
# - R wrappers used for: SFDesign, spacefillr, support, adaptMCMC.
#
# All figures are written to `figures/ch05/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch05_representative_points import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/uniformity_1d.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/uniform_design_2d.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/discrepancy_integration.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/transformation_methods.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/rosenblatt_transformation.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/support_points.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch05/support_points_advanced.png'),
# ...

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
