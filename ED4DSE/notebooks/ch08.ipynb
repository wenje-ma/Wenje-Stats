# %% [markdown]
# # Chapter 8: Multi-level and Mixture Designs
#
# This notebook reproduces the figures in `R/files/Ch8.R` using the Python implementation in `src/pyexpdes/chapters/ch08_multilevel_mixture.py`.
#
# **Sections covered:**
# - 8.1 Two-level Designs (Fractional Factorial, Half-normal plot)
# - 8.2 Bayesian-inspired Designs (Kriging + HiGarrote)
# - 8.3 Designs with more than two levels (L18 orthogonal array, MaxPro, Energy)
# - 8.4 Mixture designs (Simplex Lattice, Simplex Centroid, Ternary plots)
#
# **Policy**
# - Python-first implementation for plotting.
# - R wrappers used for: rkriging, HiGarrote, DoE.base, twinning, mixexp.
#
# All figures are written to `figures/ch08/` and displayed below.

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

from pyexpdes.chapters.ch08_multilevel_mixture import generate_figures

out_dir, fig_paths = generate_figures(use_r=True)
(out_dir, fig_paths)
# Out:
# (PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08'),
#  [PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/halfnormal_twolevel.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/halfnormal_bayesian.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/cast_fatigue_analysis.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/maxpro_energy_comparison.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/mixture_sld_scd.png'),
#   PosixPath('/Users/ycho397/Documents/01_Projects/05_Tools_Libraries/GitHub/pyexpdes/figures/ch08/mixture_spacefilling.png')])

# %%
from IPython.display import Image, display

for p in fig_paths:
    display(Image(filename=str(p)))
